# %% [markdown]
# ### Importar Librerías

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import datetime as dt

# %% [markdown]
# ### Importar Archivos

# %%
df_c1 = pd.read_csv('DATOSCLIENTE1.csv')
df_c2 = pd.read_csv('DATOSCLIENTE2.csv')
df_c3 = pd.read_csv('DATOSCLIENTE3.csv')
df_c4 = pd.read_csv('DATOSCLIENTE4.csv')
df_c5 = pd.read_csv('DATOSCLIENTE5.csv')
df_c6 = pd.read_csv('DATOSCLIENTE6.csv')
df_c7 = pd.read_csv('DATOSCLIENTE7.csv')
df_c8 = pd.read_csv('DATOSCLIENTE8.csv')
df_c9 = pd.read_csv('DATOSCLIENTE9.csv')
df_c10 = pd.read_csv('DATOSCLIENTE10.csv')
df_c11 = pd.read_csv('DATOSCLIENTE11.csv')
df_c12 = pd.read_csv('DATOSCLIENTE12.csv')
df_c13 = pd.read_csv('DATOSCLIENTE13.csv')
df_c14 = pd.read_csv('DATOSCLIENTE14.csv')
df_c15 = pd.read_csv('DATOSCLIENTE15.csv')
df_c16 = pd.read_csv('DATOSCLIENTE16.csv')
df_c17 = pd.read_csv('DATOSCLIENTE17.csv')
df_c18 = pd.read_csv('DATOSCLIENTE18.csv')
df_c19 = pd.read_csv('DATOSCLIENTE19.csv')
df_c20 = pd.read_csv('DATOSCLIENTE20.csv')
df_c21 = pd.read_csv('DATOSCLIENTE21.csv')
df_c22 = pd.read_csv('DATOSCLIENTE22.csv')
df_c23 = pd.read_csv('DATOSCLIENTE23.csv')
df_c24 = pd.read_csv('DATOSCLIENTE24.csv')
df_c25 = pd.read_csv('DATOSCLIENTE25.csv')
df_c26 = pd.read_csv('DATOSCLIENTE26.csv')
df_c27 = pd.read_csv('DATOSCLIENTE27.csv')
df_c28 = pd.read_csv('DATOSCLIENTE28.csv')
df_c29 = pd.read_csv('DATOSCLIENTE29.csv')
df_c30 = pd.read_csv('DATOSCLIENTE30.csv')

# %%
df_c1['Cliente'] = 'Cliente 1'
df_c1['Fecha'] = pd.to_datetime(df_c1['Fecha'], format='mixed')
df_c2['Cliente'] = 'Cliente 2'
df_c3['Cliente'] = 'Cliente 3'
df_c4['Cliente'] = 'Cliente 4'
df_c5['Cliente'] = 'Cliente 5'
df_c6['Cliente'] = 'Cliente 6'
df_c7['Cliente'] = 'Cliente 7'
df_c8['Cliente'] = 'Cliente 8'
df_c9['Cliente'] = 'Cliente 9'
df_c10['Cliente'] = 'Cliente 10'
df_c11['Cliente'] = 'Cliente 11'
df_c12['Cliente'] = 'Cliente 12'
df_c13['Cliente'] = 'Cliente 13'
df_c14['Cliente'] = 'Cliente 14'
df_c15['Cliente'] = 'Cliente 15'
df_c16['Cliente'] = 'Cliente 16'
df_c17['Cliente'] = 'Cliente 17'
df_c18['Cliente'] = 'Cliente 18'
df_c19['Cliente'] = 'Cliente 19'
df_c20['Cliente'] = 'Cliente 20'
df_c21['Cliente'] = 'Cliente 21'
df_c22['Cliente'] = 'Cliente 22'
df_c23['Cliente'] = 'Cliente 23'
df_c24['Cliente'] = 'Cliente 24'
df_c25['Cliente'] = 'Cliente 25'
df_c26['Cliente'] = 'Cliente 26'
df_c27['Cliente'] = 'Cliente 27'
df_c28['Cliente'] = 'Cliente 28'
df_c29['Cliente'] = 'Cliente 29'
df_c30['Cliente'] = 'Cliente 30'

# %%
# Unir todos los dataframes
df = pd.concat([df_c1, df_c2, df_c3, df_c4, df_c5, df_c6, df_c7, df_c8, df_c9, df_c10,
                df_c11, df_c12, df_c13, df_c14, df_c15, df_c16, df_c17, df_c18, df_c19, df_c20,
                df_c21, df_c22, df_c23, df_c24, df_c25, df_c26, df_c27, df_c28, df_c29, df_c30], ignore_index=True)

# %%
sectores = pd.read_excel('sector_economico_clientes.xlsx')
sectores.head()
# Out:
#      Cliente:                                  Sector Económico:
# 0  Cliente 1   Elaboración de cacao y chocolate y de producto...
# 1   Cliente 2  Elaboración de cacao y chocolate y de producto...
# 2   Cliente 3  Elaboración de cacao y chocolate y de producto...
# 3   Cliente 4  Elaboración de cacao y chocolate y de producto...
# 4   Cliente 5  Elaboración de cacao y chocolate y de producto...

# %% [markdown]
# ### Graficar tendencias

# %%
df_c1.tail()
# Out:
#                     Fecha  Active_energy  Reactive_energy  Voltaje_FA
# 19676 2023-03-31 20:00:00       1.511845         0.642091  473.424130  \
# 19677 2023-03-31 21:00:00       1.395845         0.687746  537.231219
# 19678 2023-03-31 22:00:00       0.976828         0.442356  489.302253
# 19679 2023-03-31 23:00:00       0.979561         0.451811  460.399523
# 19680 2023-01-04 00:00:00       0.693789         0.495557  476.589827
#
#        Voltaje_FC    Cliente
# 19676  558.087820  Cliente 1
# 19677  497.526966  Cliente 1
# 19678  519.647463  Cliente 1
# 19679  493.639109  Cliente 1
# 19680  535.550394  Cliente 1

# %%
fig = px.line(df_c1, x='Fecha', y='Active_energy', title='Consumo de energía activa', color='Cliente')
fig.show()

# %%
df['Fecha'] = pd.to_datetime(df['Fecha'])
fig = px.line(df[df['Cliente']=='Cliente 14'], x='Fecha', y='Active_energy', title='Consumo de energía activa', color='Cliente')
fig.show()
